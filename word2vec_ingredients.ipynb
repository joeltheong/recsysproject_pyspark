# %%
import os
import sys
import logging

import numpy as np
import pandas as pd 

from gensim.models import Word2Vec

import config
from ingredient_parser import ingredient_parser

# %%
import pandas as pd
import nltk
import string
import ast
import re
import unidecode
import nltk.corpus as corpus

#nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from collections import Counter
#import config

# %%
sys.path.append('..')

if sys.platform == 'linux':
    path = config.LINUX_PATH
else:
    path = config.OS_PATH
os.chdir(path)

# %%
sys.path.append('..')
path = config.OS_PATH

# %%
data = pd.read_csv('input/df_recipes.csv')
data['parsed'] = data.ingredients.apply(ingredient_parser)
data.head()
# Out:
#                                          name  \
# 0  arriba   baked winter squash mexican style
# 1            a bit different  breakfast pizza
# 2                     beat this  banana bread
# 3               better than sex  strawberries
# 4             better then bush s  baked beans
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['preheat oven to 350 degrees', 'butter two 9x...
# 3  ['crush vanilla wafers into fine crumbs and li...
# 4  ['in a very large sauce pan cover the beans an...
#
#                                          ingredients  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['sugar', 'unsalted butter', 'bananas', 'eggs'...
# 3  ['vanilla wafers', 'butter', 'powdered sugar',...
# 4  ['great northern bean', 'chicken bouillon cube...
#
#                                   ingredients_parsed  \
# 0  winter squash mexican seasoning mixed spice ho...
# 1  prepared pizza crust sausage patty egg milk sa...
# 2  sugar unsalted butter banana egg fresh lemon j...
# 3  vanilla wafer butter powdered sugar egg whippi...
# 4  great northern bean chicken bouillon cube dark...
#
#                                               parsed
# 0  [winter squash, mexican seasoning, mixed spice...
# 1  [prepared pizza crust, sausage patty, egg, mil...
# 2  [sugar, unsalted butter, banana, egg, fresh le...
# 3  [vanilla wafer, butter, powdered sugar, egg, w...
# 4  [great northern bean, chicken bouillon cube, d...

# %%
data = pd.read_csv('input/df_parsed.csv')

data.head()
# Out:
#                                          name  \
# 0  arriba   baked winter squash mexican style
# 1            a bit different  breakfast pizza
# 2                     beat this  banana bread
# 3               better than sex  strawberries
# 4             better then bush s  baked beans
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['preheat oven to 350 degrees', 'butter two 9x...
# 3  ['crush vanilla wafers into fine crumbs and li...
# 4  ['in a very large sauce pan cover the beans an...
#
#                                               parsed  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['sugar', 'unsalted butter', 'banana', 'egg', ...
# 3  ['vanilla wafer', 'butter', 'powdered sugar', ...
# 4  ['great northern bean', 'chicken bouillon cube...
#
#                                          ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['sugar', 'unsalted butter', 'bananas', 'eggs'...
# 3  ['vanilla wafers', 'butter', 'powdered sugar',...
# 4  ['great northern bean', 'chicken bouillon cube...

# %%
data['parsed'].iloc[0]
# Out:
# ['winter squash',
#  'mexican seasoning',
#  'mixed spice',
#  'honey',
#  'butter',
#  'olive oil',
#  'salt']

# %%
data['parsed'].dtype
# Out:
# dtype('O')

# %%
# get corpus with the documents sorted in alphabetical order
def get_and_sort_corpus(data):
    corpus_sorted = []
    for doc in data.parsed.values:
        doc.sort()
        corpus_sorted.append(doc)
    return corpus_sorted

corpus = get_and_sort_corpus(data)
print(f"Length of corpus: {len(corpus)}")
# Out:
# Length of corpus: 94564

# %%
corpus
# Out:
# [['butter',
#   'honey',
#   'mexican seasoning',
#   'mixed spice',
#   'olive oil',
#   'salt',
#   'winter squash'],
#  ['cheese',
#   'egg',
#   'milk',
#   'prepared pizza crust',
#   'salt and pepper',
#   'sausage patty'],
#  ['baking soda',
#   'banana',
#   'cake flour',
#   'egg',
#   'fresh lemon juice',
#   'orange rind',
#   'salt',
#   'sugar',
#   'unsalted butter'],
#  ['butter',
#   'egg',
#   'powdered sugar',
#   'strawberry',
#   'vanilla wafer',
#   'walnut',
#   'whipping cream'],
#  ['bacon',
#   'black pepper',
#   'chicken bouillon cube',
#   'chili powder',
#   'cornstarch',
#   'dark brown sugar',
#   'garlic powder',
#   'great northern bean',
#   'molasses',
#   'mustard powder',
#   'onion',
#   'salt',
#   'water'],
#  ['chicken rice soup',
#   'dry mustard',
#   'flour',
#   'garlic powder',
#   'lean pork chop',
#   'oil',
#   'salt'],
#  ['cheese', 'cornstarch', 'egg roll wrap', 'oil', 'whole green chilies'],
#  ['butterscotch chip', 'chinese noodle', 'salted peanut'],
#  ['beef broth',
#   'celery',
#   'cooking oil',
#   'ground pork',
#   'hamburger bun',
#   'onion',
#   'soy sauce'],
#  ['boiling potato',
#   'coarse salt',
#   'fresh ground black pepper',
#   'fresh spinach leaf',
#   'nutmeg',
#   'salt',
#   'unsalted butter',
#   'water'],
#  ['all purpose flour',
#   'boneless skinless chicken breast half',
#   'condensed cream of chicken soup',
#   'cornstarch',
#   'egg',
#   'garlic powder',
#   'oil',
#   'paprika',
#   'salt and pepper',
#   'seasoning salt'],
#  ['butter', 'egg yolk', 'juice of', 'salt', 'white pepper'],
#  ['black cumin',
#   'ground black pepper',
#   'ground coriander',
#   'ground cumin',
#   'ground ginger',
#   'ground turmeric'],
#  ['black pepper',
#   'celery',
#   'chili powder',
#   'diced tomato',
#   'garlic',
#   'green pepper',
#   'jalapeno',
#   'kidney bean',
#   'onion',
#   'red pepper flake',
#   'salt',
#   'vegetarian ground beef'],
#  ['margarine', 'red potato', 'rosemary'],
#  ['black bean',
#   'broccoli floret',
#   'broccoli stem',
#   'carrot',
#   'celery',
#   'chicken stock',
#   'cornstarch',
#   'dried oregano',
#   'dried sweet basil leaf',
#   'dried thyme',
#   'dry white wine',
#   'heavy cream',
#   'onion',
#   'salt fresh ground pepper',
#   'smoked chicken',
#   'tabasco sauce',
#   'unsalted butter',
#   'worcestershire sauce'],
#  ['butter', 'dry ranch dressing mix', 'french bread'],
#  ['black pepper',
#   'dry mustard',
#   'egg substitute',
#   'fresh breadcrumb',
#   'ground venison',
#   'non fat powdered milk',
#   'onion',
#   'salt',
#   'water',
#   'worcestershire sauce'],
#  ['frozen juice concentrate', 'milk', 'plain yogurt'],
#  ['black pepper',
#   'condensed cream of mushroom soup',
#   'crouton',
#   'egg',
#   'frozen chopped spinach',
#   'onion',
#   'salt',
#   'sharp cheddar cheese'],
#  ['celery seed',
#   'diced pimento',
#   'fat free mayonnaise',
#   'garlic',
#   'green onion',
#   'low fat sour cream',
#   'pepper',
#   'plain low fat yogurt',
#   'prepared mustard',
#   'red potato',
#   'salt',
#   'sugar',
#   'white wine vinegar'],
#  ['egg',
#   'frozen chopped spinach',
#   'garlic powder',
#   'margarine',
#   'onion',
#   'oregano',
#   'sage',
#   'soft breadcrumb'],
#  ['condensed cream of mushroom garlic soup',
#   'cooking oil',
#   'cornbread mix',
#   'cream of mushroom soup',
#   'frozen vegetable',
#   'ground beef',
#   'onion',
#   'salt pepper'],
#  ['angel hair pasta',
#   'garlic',
#   'green onion',
#   'honey',
#   'soy sauce',
#   'stir fry vegetable',
#   'toasted sesame oil',
#   'toasted sesame seed'],
#  ['american cheese',
#   'beer',
#   'cayenne',
#   'garlic',
#   'ground beef',
#   'prepared yellow mustard',
#   'salt pepper',
#   'sugar'],
#  ['basil',
#   'flat leaf parsley',
#   'frozen french fry',
#   'oil',
#   'oregano',
#   'parmesan cheese',
#   'salt freshly ground black pepper'],
#  ['all purpose flour',
#   'baking powder',
#   'butter',
#   'egg',
#   'icing sugar',
#   'milk',
#   'salt',
#   'shortening',
#   'sugar',
#   'vanilla'],
#  ['carrot',
#   'cinnamon',
#   'coconut',
#   'crushed pineapple',
#   'egg',
#   'nutmeg',
#   'oil',
#   'pecan',
#   'vanilla instant pudding mix',
#   'water',
#   'yellow cake mix'],
#  ['butter',
#   'egg',
#   'heavy cream',
#   'honey',
#   'jalapeno',
#   'jiffy corn muffin mix',
#   'onion',
#   'red bell pepper',
#   'sharp cheddar cheese',
#   'whole kernel corn'],
#  ['baking powder',
#   'baking soda',
#   'brown sugar',
#   'butter',
#   'cinnamon',
#   'crushed pineapple',
#   'dry yeast',
#   'egg',
#   'flour',
#   'milk',
#   'nut',
#   'raisin',
#   'salt',
#   'sugar',
#   'vanilla',
#   'vegetable oil',
#   'water'],
#  ['cottage cheese',
#   'dried basil',
#   'egg',
#   'garlic',
#   'ground beef',
#   'ground black pepper',
#   'italian sausage',
#   'lasagna noodle',
#   'mozzarella cheese',
#   'parmesan cheese',
#   'parsley flake',
#   'ricotta cheese',
#   'salt',
#   'tomato paste',
#   'whole tomato'],
#  ['brown sugar',
#   'butter',
#   'cinnamon',
#   'instant vanilla pudding',
#   'raisin',
#   'roll'],
#  ['beef steak',
#   'brown sugar',
#   'dried dill weed',
#   'fresh garlic',
#   'fresh lemon juice',
#   'fresh parsley',
#   'honey',
#   'hot sauce',
#   'ketchup',
#   'sour cream',
#   'spicy mustard',
#   'vegetable oil'],
#  ['button mushroom',
#   'chicken breast',
#   'dried basil',
#   'dried oregano',
#   'fresh ground black pepper',
#   'fresh parsley',
#   'garlic',
#   'hot sauce',
#   'olive oil',
#   'onion',
#   'parmesan cheese',
#   'pasta',
#   'salsa',
#   'tomato',
#   'water'],
#  ['cider vinegar', 'fresh herb', 'fresh herb'],
#  ['baking powder',
#   'cream',
#   'egg',
#   'fat',
#   'flour',
#   'fresh corn',
#   'pepper',
#   'salt'],
#  ['cilantro',
#   'frozen pea',
#   'ha avocado',
#   'juice of',
#   'onion',
#   'salt',
#   'tomato'],
#  ['black pepper', 'cracker', 'mayonnaise', 'tomato'],
#  ['powdered sugar',
#   'vanilla extract',
#   'vanilla instant pudding mix',
#   'whipping cream'],
#  ['all purpose flour',
#   'baking powder',
#   'butter',
#   'carrot',
#   'cayenne pepper',
#   'celery',
#   'chili powder',
#   'clove',
#   'egg',
#   'flour',
#   'green pepper',
#   'ground cumin',
#   'monterey jack cheese',
#   'onion',
#   'oregano',
#   'salt',
#   'sliced mushroom',
#   'soy sauce',
#   'tomato',
#   'vegetable shortening',
#   'water',
#   'zucchini'],
#  ['half and half', 'salt and pepper', 'sweet butter', 'sweet corn'],
#  ['all purpose flour',
#   'baking soda',
#   'butter',
#   'egg',
#   'rind of',
#   'salt',
#   'sugar',
#   'vanilla',
#   'yogurt'],
#  ['butter',
#   'egg',
#   'flour',
#   'nut',
#   'sugar',
#   'unsweetened chocolate square',
#   'vanilla'],
#  ['black pepper',
#   'cornstarch',
#   'mushroom piece',
#   'onion',
#   'sodium free vegetable broth',
#   'tabasco sauce',
#   'tomato puree',
#   'white wine'],
#  ['albacore tuna in water',
#   'bibb lettuce',
#   'black pepper',
#   'fresh basil',
#   'garlic',
#   'light olive oil',
#   'red sweet bell pepper',
#   'red wine vinegar',
#   'salt',
#   'scallion',
#   'white kidney bean'],
#  ['bacon',
#   'beef consomme',
#   'black pepper',
#   'butter',
#   'carrot',
#   'celery',
#   'crushed tomato',
#   'dry white wine',
#   'garlic',
#   'ground pork',
#   'lean ground beef',
#   'milk',
#   'nutmeg',
#   'olive oil',
#   'onion',
#   'oregano',
#   'penne pasta',
#   'red pepper flake',
#   'rubbed sage',
#   'salt'],
#  ['brown sugar',
#   'celery',
#   'cucumber',
#   'elbow macaroni',
#   'fresh tomato',
#   'green pepper',
#   'ketchup',
#   'lemon juice',
#   'oil',
#   'onion'],
#  ['baking powder',
#   'brown sugar',
#   'cocoa',
#   'flour',
#   'hot water',
#   'milk',
#   'salt',
#   'sugar',
#   'vanilla',
#   'vegetable oil'],
#  ['banana', 'mayonnaise', 'white bread'],
#  ['all purpose flour',
#   'boneless skinless chicken thigh',
#   'breadcrumb',
#   'chicken stock',
#   'dried oregano',
#   'dried thyme',
#   'dry white wine',
#   'fresh ground black pepper',
#   'garlic powder',
#   'lean ground beef',
#   'milk',
#   'onion',
#   'poultry seasoning',
#   'salt',
#   'vegetable oil'],
#  ['cream cheese', 'lemon juice', 'liquid smoke', 'onion', 'salmon', 'salt'],
#  ['bean sprout',
#   'brown sugar',
#   'carrot',
#   'desiccated coconut',
#   'garlic',
#   'ginger',
#   'green bean',
#   'ground cayenne pepper',
#   'ground coriander',
#   'ground cumin',
#   'onion',
#   'peanut',
#   'peanut oil',
#   'red chili pepper',
#   'sambal oelek',
#   'soy sauce',
#   'tempeh',
#   'tomato',
#   'vegetable stock',
#   'water'],
#  ['dried breadcrumb',
#   'egg',
#   'ground beef',
#   'lemon juice',
#   'onion',
#   'salt and pepper',
#   'sugar',
#   'tomato soup',
#   'water'],
#  ['avocado',
#   'chunky salsa',
#   'fresh cilantro',
#   'hot sauce',
#   'lime juice',
#   'salt and pepper',
#   'soft silken tofu'],
#  ['beef rib',
#   'brown sugar',
#   'fresh lemon juice',
#   'ketchup',
#   'mustard',
#   'onion',
#   'salt',
#   'vegetable oil',
#   'water',
#   'worcestershire sauce'],
#  ['egg white', 'green grape', 'sugar'],
#  ['betty crocker fudge brownie mix',
#   'egg',
#   'milk chocolate candy bar',
#   'vegetable oil',
#   'water'],
#  ['baking powder',
#   'baking soda',
#   'banana',
#   'butter',
#   'chocolate chip',
#   'egg',
#   'flour',
#   'nut',
#   'salt',
#   'sugar',
#   'water'],
#  ['brown sugar',
#   'butter',
#   'chocolate chip',
#   'cream cheese',
#   'egg',
#   'flour',
#   'oreo cookie crumb',
#   'sour cream',
#   'sweetened condensed milk',
#   'vanilla'],
#  ['bean dip',
#   'cheddar cheese',
#   'cream cheese',
#   'sour cream',
#   'taco seasoning'],
#  ['chat masala',
#   'chopped tomato',
#   'cucumber',
#   'paprika',
#   'plain yogurt',
#   'potato',
#   'salt'],
#  ['baking soda',
#   'brown sugar',
#   'buttermilk',
#   'carrot',
#   'cinnamon',
#   'corn oil',
#   'egg',
#   'natural bran',
#   'raisin',
#   'salt',
#   'vanilla',
#   'whole wheat flour'],
#  ['brown sugar', 'butter', 'flour', 'pecan', 'semi sweet chocolate chip'],
#  ['butter',
#   'cappelletti pasta',
#   'cheddar cheese',
#   'chopped tomato',
#   'corn',
#   'garlic',
#   'ground beef',
#   'milk',
#   'mushroom',
#   'onion',
#   'pepper',
#   'salt',
#   'tomato soup'],
#  ['baking soda',
#   'cocoa',
#   'flour',
#   'salt',
#   'sugar',
#   'vanilla',
#   'vegetable oil',
#   'vinegar',
#   'water'],
#  ['applesauce', 'brown sugar', 'clove', 'pork loin chop'],
#  ['asian chili sauce',
#   'bean sprout',
#   'carrot',
#   'english cucumber',
#   'fresh cilantro',
#   'fresh ginger',
#   'garlic',
#   'green onion',
#   'honey',
#   'light soy sauce',
#   'rice noodle',
#   'rice wine vinegar',
#   'sesame oil'],
#  ['fish',
#   'gingerroot',
#   'low sodium soy sauce',
#   'peanut oil',
#   'rice wine',
#   'salt',
#   'scallion',
#   'sesame oil',
#   'white pepper'],
#  ['butter',
#   'cornbread',
#   'cream of chicken soup',
#   'egg',
#   'onion',
#   'sage',
#   'squash'],
#  ['cream of chicken soup',
#   'french fried onion',
#   'frozen broccoli cut',
#   'garlic powder',
#   'ground black pepper',
#   'milk',
#   'salt',
#   'sharp cheddar cheese',
#   'soy sauce'],
#  ['artichoke heart',
#   'egg',
#   'fresh garlic',
#   'oil',
#   'unsalted butter',
#   'unseasoned breadcrumb'],
#  ['barbecue sauce',
#   'black pepper',
#   'chicken',
#   'chili powder',
#   'cider vinegar',
#   'hot red pepper sauce',
#   'salt',
#   'worcestershire sauce'],
#  ['cheddar cheese',
#   'cream cheese',
#   'dry onion soup mix',
#   'frozen broccoli',
#   'ritz cracker crumb',
#   'sour cream',
#   'water chestnut'],
#  ['bouillon',
#   'budweiser beer',
#   'chili powder',
#   'coriander',
#   'cornmeal',
#   'cumin',
#   'flour',
#   'garlic clove',
#   'hunt tomato sauce',
#   'lean chuck',
#   'lean pork',
#   'louisiana hot sauce',
#   'onion',
#   'oregano leaf',
#   'paprika',
#   'sugar',
#   'unsweetened cocoa',
#   'water'],
#  ['dark brown sugar',
#   'egg',
#   'egg white',
#   'ground cinnamon',
#   'ground clove',
#   'ground ginger',
#   'heavy cream',
#   'milk',
#   'nutmeg',
#   'pie crust',
#   'pumpkin puree',
#   'salt'],
#  ['baking powder',
#   'baking soda',
#   'brown sugar',
#   'butter',
#   'chocolate chip',
#   'egg',
#   'flour',
#   'nut',
#   'oatmeal',
#   'salt',
#   'semi sweet baking chocolate',
#   'vanilla',
#   'white sugar'],
#  ['all purpose flour',
#   'baking soda',
#   'brown sugar',
#   'butter',
#   'cream cheese',
#   'egg',
#   'lemon zest',
#   'lime zest',
#   'orange flavored liqueur',
#   'pecan',
#   'pitted date',
#   'powdered sugar',
#   'salt',
#   'shortening',
#   'tequila',
#   'triple sec',
#   'warm water'],
#  ['baking powder',
#   'baking soda',
#   'butter',
#   'egg',
#   'flour',
#   'salt',
#   'sour cream',
#   'sugar',
#   'vanilla'],
#  ['butter', 'frozen whipped topping', 'oreo cooky', 'vanilla ice cream'],
#  ['butter', 'processed cheese', 'white bread'],
#  ['balsamic vinegar',
#   'fresh ground black pepper',
#   'garlic clove',
#   'london broil beef',
#   'olive oil',
#   'rosemary',
#   'soy sauce',
#   'worcestershire sauce'],
#  ['chicken broth',
#   'cornstarch',
#   'dried oregano',
#   'dried rosemary',
#   'dried thyme',
#   'dry sherry',
#   'fresh mushroom',
#   'garlic clove',
#   'hot pepper sauce',
#   'margarine',
#   'nonfat dry milk powder',
#   'nonfat milk',
#   'parmesan cheese',
#   'salt and black pepper',
#   'spicy brown mustard',
#   'teriyaki sauce'],
#  ['bacon', 'butter', 'real maple syrup', 'refrigerated buttermilk biscuit'],
#  ['horseradish',
#   'mayonnaise',
#   'tabasco sauce',
#   'velveeta cheese',
#   'worcestershire sauce'],
#  ['lemon juice', 'red wine vinegar', 'water'],
#  ['berry',
#   'ground flax seed',
#   'i believe not butter spread',
#   'old fashioned oat',
#   'sugar free syrup',
#   'water'],
#  ['bacon',
#   'celery',
#   'cheddar cheese',
#   'chicken broth',
#   'chive',
#   'liquid smoke',
#   'onion',
#   'red potato',
#   'salt',
#   'sour cream',
#   'velveeta cheese',
#   'white pepper'],
#  ['cheddar cheese',
#   'cracker',
#   'egg',
#   'ground beef',
#   'onion',
#   'pickle',
#   'salt and pepper',
#   'thousand island dressing'],
#  ['cottage cheese', 'egg', 'feta', 'milk', 'oil', 'phyllo dough'],
#  ['baking soda',
#   'egg',
#   'flour',
#   'maraschino cherry',
#   'mincemeat',
#   'mixed candied fruit',
#   'sweetened condensed milk',
#   'walnut'],
#  ['cider vinegar',
#   'dry mustard',
#   'garlic clove',
#   'ketchup',
#   'miracle whip',
#   'paprika',
#   'pepper',
#   'salt',
#   'sugar',
#   'tabasco sauce',
#   'vegetable oil'],
#  ['extra virgin olive oil',
#   'italian parsley',
#   'juice of',
#   'kalamata olive',
#   'kosher salt freshly ground black pepper',
#   'oregano',
#   'pepperoncini pepper',
#   'red bell pepper',
#   'red onion',
#   'red ripe tomato',
#   'red wine vinegar',
#   'seedless cucumber',
#   'shallot',
#   'tuna in vegetable oil',
#   'water packed artichoke heart'],
#  ['chili powder',
#   'dry roasted cashew',
#   'garlic clove',
#   'margarine',
#   'mushroom',
#   'nutmeg',
#   'parsley',
#   'vegetable bouillon cube',
#   'water'],
#  ['ice cube', 'mango', 'orange', 'strawberry', 'vanilla bean'],
#  ['fresh rosemary',
#   'garlic clove',
#   'leek',
#   'olive oil',
#   'russet potato',
#   'salt and pepper',
#   'vegetable broth',
#   'white bean'],
#  ['beef bouillon cube',
#   'black pepper',
#   'boiling water',
#   'dried oregano',
#   'dried thyme',
#   'garlic clove',
#   'garlic powder',
#   'rump roast',
#   'salt',
#   'tabasco sauce',
#   'worcestershire sauce'],
#  ['ginger', 'honey', 'milk', 'tea bag', 'water'],
#  ['baking powder',
#   'baking soda',
#   'brown sugar',
#   'egg',
#   'flour',
#   'milk',
#   'molasses',
#   'natural bran',
#   'oil',
#   'raisin',
#   'salt',
#   'sesame seed',
#   'sunflower seed'],
#  ['canned jalapeno slice',
#   'cayenne pepper',
#   'chili powder',
#   'cornstarch',
#   'dried onion flake',
#   'garlic powder',
#   'onion powder',
#   'salt',
#   'sugar',
#   'tomato paste',
#   'vinegar',
#   'water'],
#  ['baking powder',
#   'baking soda',
#   'brown sugar',
#   'butter',
#   'cake flour',
#   'corn flake',
#   'egg',
#   'nut',
#   'quick cooking oat',
#   'raisin',
#   'salt',
#   'shredded coconut',
#   'vanilla'],
#  ['cheddar cheese',
#   'chili with bean',
#   'corn chip',
#   'onion',
#   'salsa',
#   'sour cream'],
#  ['butter',
#   'fresh green bean',
#   'ground black pepper',
#   'kosher salt',
#   'mixed herb',
#   'olive oil',
#   'onion',
#   'walnut'],
#  ['american cheese', 'ham', 'hamburger bun', 'ketchup', 'sweet pickle relish'],
#  ['brown sugar',
#   'egg',
#   'ground beef',
#   'ketchup',
#   'lipton onion soup mix',
#   'seasoned bread crumb'],
#  ['bulk pork sausage',
#   'garlic powder',
#   'ground chuck',
#   'ground pepper',
#   'oregano',
#   'rye cocktail bread',
#   'velveeta cheese',
#   'worcestershire sauce'],
#  ['brown sugar',
#   'butter',
#   'caster sugar',
#   'egg',
#   'glace cherry',
#   'milk',
#   'pineapple in syrup',
#   'self raising flour',
#   'vanilla essence'],
#  ['broccoli floret',
#   'brown rice',
#   'carrot',
#   'egg',
#   'olive oil',
#   'pea',
#   'sliced mushroom',
#   'soy sauce'],
#  ['egg white',
#   'pumpkin',
#   'pumpkin pie spice',
#   'reduced fat graham cracker crust',
#   'skim milk',
#   'splenda sugar substitute'],
#  ['all purpose flour',
#   'butter',
#   'egg',
#   'instant vanilla pudding',
#   'water',
#   'whipped dessert topping mix'],
#  ['celery',
#   'dijon mustard',
#   'fresh ground pepper',
#   'hard boiled egg',
#   'milk',
#   'miracle whip',
#   'mustard',
#   'potato',
#   'salt',
#   'sugar',
#   'white onion',
#   'white pepper'],
#  ['black pepper',
#   'boneless pork chop',
#   'dry onion soup mix',
#   'long grain rice',
#   'vegetable oil',
#   'water'],
#  ['allspice',
#   'boneless skinless chicken breast',
#   'brown sugar',
#   'cayenne',
#   'chili powder',
#   'chive',
#   'cinnamon',
#   'clove',
#   'crushed tomato',
#   'garlic clove',
#   'ginger',
#   'habanero pepper',
#   'jamaican jerk spice',
#   'lime juice',
#   'nutmeg',
#   'olive oil',
#   'onion',
#   'onion flake',
#   'pepper',
#   'red pepper',
#   'rum',
#   'sage',
#   'thyme'],
#  ['apple juice',
#   'banana',
#   'ice',
#   'non fat vanilla frozen yogurt',
#   'strawberry'],
#  ['all purpose flour',
#   'butter',
#   'candy cane',
#   'egg',
#   'peppermint extract',
#   'peppermint oreo',
#   'salt',
#   'sugar',
#   'unsweetened chocolate',
#   'unsweetened cocoa powder',
#   'vanilla extract'],
#  ['celery',
#   'cheddar cheese',
#   'frozen pea',
#   'hard boiled egg',
#   'mayonnaise',
#   'mustard',
#   'onion',
#   'seasoning salt',
#   'sugar',
#   'sweet pickle relish'],
#  ['all purpose flour',
#   'black pepper',
#   'butter',
#   'buttermilk',
#   'cayenne pepper',
#   'chicken piece',
#   'dijon mustard',
#   'dried thyme',
#   'dry breadcrumb',
#   'fresh garlic',
#   'garlic powder',
#   'hot pepper sauce',
#   'oil',
#   'onion',
#   'paprika',
#   'parmesan cheese',
#   'seasoning salt'],
#  ['cooking onion', 'pickling spice', 'white vinegar'],
#  ['carrot',
#   'chicken broth',
#   'cooked chicken',
#   'cooked pasta',
#   'egg',
#   'pea',
#   'soy sauce'],
#  ['black pepper',
#   'cream of mushroom soup',
#   'dijon mustard',
#   'dried onion flake',
#   'dried parsley flake',
#   'garlic powder',
#   'ground cinnamon',
#   'ground clove',
#   'ground veal',
#   'salt'],
#  ['bacon',
#   'egg',
#   'fresh chive',
#   'mild cheddar cheese',
#   'paprika',
#   'sour cream',
#   'white vinegar'],
#  ['chicken breast',
#   'cracked black pepper',
#   'dried basil',
#   'dried oregano',
#   'dried parsley',
#   'garlic clove',
#   'garlic salt',
#   'lemon juice',
#   'olive oil',
#   'salt',
#   'sandwich bun',
#   'white vinegar'],
#  ['butter', 'marshmallow', 'rice krispies'],
#  ['baking potato',
#   'chickpea',
#   'coriander',
#   'fresh coriander',
#   'garlic clove',
#   'ground cumin',
#   'low fat yogurt',
#   'olive oil',
#   'salt freshly ground black pepper',
#   'tahini'],
#  ['cider vinegar',
#   'feta cheese',
#   'fresh dill',
#   'garlic clove',
#   'light mayonnaise',
#   'red bell pepper',
#   'skinless chicken breast half'],
#  ['cheese ravioli',
#   'garlic salt',
#   'italian seasoning',
#   'lean ground beef',
#   'mozzarella cheese',
#   'spaghetti sauce'],
#  ['barbecue sauce',
#   'chicken piece',
#   'lemon juice',
#   'orange marmalade',
#   'worcestershire sauce'],
#  ['coriander',
#   'garlic powder',
#   'ground black pepper',
#   'ground red pepper',
#   'onion powder',
#   'paprika',
#   'salt',
#   'turmeric'],
#  ['butter', 'heavy cream', 'semisweet chocolate', 'sugar'],
#  ['cherry pie filling',
#   'crushed pineapple',
#   'frozen whipped topping',
#   'pecan',
#   'small marshmallow',
#   'sweetened condensed milk'],
#  ['boneless eye of round beef steak',
#   'canola oil',
#   'mozzarella cheese',
#   'onion',
#   'parmesan cheese',
#   'pepper',
#   'pizza sauce',
#   'plain flour',
#   'salt'],
#  ['all purpose flour',
#   'bacon grease',
#   'boneless country style rib',
#   'golden mushroom soup',
#   'ground black pepper',
#   'oregano',
#   'seasoning salt',
#   'soup mix'],
#  ['butter', 'egg', 'flour', 'fruit', 'milk', 'sugar'],
#  ['apple',
#   'baby carrot',
#   'butter',
#   'cardamom',
#   'crescent roll dough',
#   'ground cinnamon',
#   'honey',
#   'sugar'],
#  ['garlic salt',
#   'italian seasoning',
#   'mozzarella cheese',
#   'olive oil',
#   'refrigerated biscuit'],
#  ['active dry yeast', 'butter', 'flour', 'milk', 'salt', 'sugar', 'water'],
#  ['brown sugar',
#   'cayenne pepper',
#   'dried sage',
#   'fat free evaporated milk',
#   'flour',
#   'garlic powder',
#   'ground marjoram',
#   'lean ground turkey',
#   'onion flake',
#   'pepper',
#   'poultry seasoning',
#   'salt',
#   'skim milk'],
#  ['carrot',
#   'curry powder',
#   'garam masala',
#   'garlic clove',
#   'ghee',
#   'kidney bean',
#   'onion',
#   'potato',
#   'salt and pepper',
#   'tabasco sauce',
#   'water'],
#  ['ice cube', 'orange juice', 'orange slice', 'ouzo'],
#  ['crabmeat',
#   'cream of celery soup',
#   'cream of mushroom soup',
#   'half and half',
#   'milk',
#   'old bay seasoning',
#   'pepper',
#   'red pepper',
#   'salt',
#   'sherry wine'],
#  ['black bean',
#   'chili powder',
#   'cumin',
#   'dry breadcrumb',
#   'flour',
#   'frozen corn',
#   'garlic',
#   'green chili sauce',
#   'oil',
#   'onion',
#   'salsa'],
#  ['bell pepper',
#   'celery',
#   'cheese',
#   'fresh parsley',
#   'garlic clove',
#   'ground turkey',
#   'olive oil',
#   'onion',
#   'salt and pepper',
#   'spike seasoning',
#   'tomato',
#   'worcestershire sauce'],
#  ['chicken piece', 'ketchup', 'oil', 'smooth peanut butter', 'soy sauce'],
#  ['fresh basil',
#   'fresh oregano',
#   'garlic clove',
#   'olive oil',
#   'salt and pepper',
#   'tomato'],
#  ['old bay seasoning', 'plain tomato juice'],
#  ['banana',
#   'bay leaf',
#   'butter',
#   'canned pumpkin',
#   'canned unsweetened coconut milk',
#   'carrot',
#   'chicken stock',
#   'cinnamon',
#   'coriander',
#   'curry powder',
#   'garlic clove',
#   'ground allspice',
#   'ground nutmeg',
#   'onion',
#   'pumpkin seed',
#   'shallot',
#   'sweetened condensed milk'],
#  ['black pepper', 'butter', 'dried beef', 'flour', 'milk'],
#  ['carrot',
#   'onion',
#   'pepper',
#   'potato',
#   'salt',
#   'split pea',
#   'turnip',
#   'water'],
#  ['bibb lettuce',
#   'cayenne pepper',
#   'cheddar cheese',
#   'fresh thyme',
#   'ground cumin',
#   'hamburger bun',
#   'lean ground beef',
#   'mayonnaise',
#   'onion',
#   'papaya',
#   'salt',
#   'tomato',
#   'white pepper',
#   'worcestershire sauce'],
#  ['baking soda',
#   'cinnamon',
#   'egg',
#   'fat',
#   'flour',
#   'salt',
#   'sugar',
#   'vanilla',
#   'walnut',
#   'zucchini'],
#  ['apple',
#   'dry white wine',
#   'lemon',
#   'lemon flavored vodka',
#   'lemon juice',
#   'lemonade',
#   'lime',
#   'lime juice',
#   'peach',
#   'peach puree',
#   'peach schnapps'],
#  ['barbecue sauce',
#   'brown sugar',
#   'ground moose',
#   'hot sauce',
#   'ketchup',
#   'onion',
#   'prepared mustard',
#   'salt and pepper'],
#  ['colby cheese',
#   'hard boiled egg',
#   'mayonnaise',
#   'miracle whip',
#   'small shell pasta',
#   'sugar',
#   'sweet onion',
#   'sweet pickle juice'],
#  ['blueberry', 'cinnamon', 'nutmeg', 'sugar'],
#  ['cheddar cheese',
#   'diced green chilies',
#   'knorr vegetable soup mix',
#   'sour cream',
#   'tomato and green chilies'],
#  ['butter',
#   'flour',
#   'frozen spinach',
#   'ground black pepper',
#   'half and half',
#   'onion',
#   'parmesan cheese',
#   'salt',
#   'sour cream',
#   'water'],
#  ['chocolate ice cream',
#   'chocolate syrup',
#   'ice',
#   'strong coffee',
#   'sugar',
#   'whipped cream'],
#  ['baking powder',
#   'butter',
#   'egg',
#   'flour',
#   'icing sugar',
#   'lemon',
#   'milk',
#   'starch',
#   'sugar',
#   'vanilla'],
#  ['brown sugar', 'cool whip', 'cream cheese', 'salt', 'vanilla'],
#  ['baking powder', 'egg', 'fat', 'milk', 'salt', 'sugar', 'white flour'],
#  ['butter',
#   'cinnamon',
#   'cream cheese',
#   'crescent roll dough',
#   'jam',
#   'sugar',
#   'vanilla'],
#  ['bacon',
#   'black pepper',
#   'butter',
#   'celery',
#   'chicken broth',
#   'dill pickle relish',
#   'extra sharp cheddar cheese',
#   'flour',
#   'garlic powder',
#   'half and half',
#   'lean ground beef',
#   'onion',
#   'parsley',
#   'russet potato',
#   'velveeta cheese',
#   'whole tomato',
#   'yellow mustard'],
#  ['butter', 'evaporated milk', 'sugar', 'unsweetened chocolate square'],
#  ['beet',
#   'honey',
#   'lemon juice',
#   'onion',
#   'salt',
#   'sour cream',
#   'water',
#   'white pepper'],
#  ['arborio rice',
#   'blue cheese',
#   'butter',
#   'chicken stock',
#   'dry white wine',
#   'fresh ground black pepper',
#   'fresh sage',
#   'garlic clove',
#   'juice and zest of',
#   'leek',
#   'olive oil',
#   'parmesan cheese',
#   'smoked bacon'],
#  ['apple juice', 'blackberry', 'blueberry', 'raspberry', 'strawberry'],
#  ['beef base', 'cornstarch', 'pepper', 'water'],
#  ['avocado',
#   'cabbage',
#   'cheese',
#   'chili powder',
#   'fish fillet',
#   'fresh cilantro',
#   'ground black pepper',
#   'hot sauce',
#   'lime juice',
#   'paprika',
#   'salsa',
#   'salt',
#   'tortilla'],
#  ['baby spinach',
#   'carrot',
#   'chicken broth',
#   'ditalini',
#   'dried basil',
#   'dried oregano',
#   'fresh coarse ground black pepper',
#   'fresh corn',
#   'garlic clove',
#   'great northern bean',
#   'olive oil',
#   'onion',
#   'pesto sauce',
#   'salt',
#   'yellow squash',
#   'zucchini'],
#  ['cayenne pepper',
#   'cayenne pepper sauce',
#   'cornstarch',
#   'egg yolk',
#   'fresh coarse ground black pepper',
#   'garlic powder',
#   'granulated sugar',
#   'vegetable oil',
#   'water',
#   'worcestershire sauce'],
#  ['blue cheese',
#   'celery rib',
#   'egg',
#   'lemon pepper seasoning',
#   'mayonnaise',
#   'parsley',
#   'tabasco sauce'],
#  ['cayenne pepper',
#   'cayenne pepper sauce',
#   'chicken drummettes',
#   'flour',
#   'paprika',
#   'pepper',
#   'salt',
#   'tabasco sauce',
#   'unsalted butter'],
#  ['butter',
#   'french bread',
#   'garlic salt',
#   'hamburger',
#   'onion',
#   'pepper',
#   'salt',
#   'tomato soup',
#   'velveeta cheese'],
#  ['egg',
#   'fresh parsley',
#   'green onion',
#   'lump crabmeat',
#   'mayonnaise',
#   'old bay seasoning',
#   'panko breadcrumb',
#   'plain breadcrumb',
#   'prepared yellow mustard',
#   'red bell pepper',
#   'vegetable oil'],
#  ['carrot',
#   'cream cheese',
#   'firm tofu',
#   'fresh parsley',
#   'garlic clove',
#   'lasagna noodle',
#   'lemon juice',
#   'nutmeg',
#   'nutritional yeast',
#   'spaghetti sauce',
#   'spinach leaf',
#   'vegetable broth'],
#  ['adobo seasoning',
#   'avocado',
#   'black bean',
#   'cheddar cheese',
#   'chicken breast',
#   'cumin',
#   'diced tomato with chile and cilantro',
#   'extra virgin olive oil',
#   'fresh cilantro',
#   'guacamole seasoning mix',
#   'lettuce',
#   'mexican rice',
#   'paprika',
#   'pepper',
#   'salt',
#   'sour cream',
#   'sweet corn',
#   'taco seasoning'],
#  ['cream cheese', 'crushed pineapple', 'pineapple juice', 'whipped cream'],
#  ['beef consomme soup',
#   'butter',
#   'french onion soup',
#   'rice',
#   'sliced water chestnut'],
#  ['chicken stock',
#   'cooked chicken',
#   'frozen pea',
#   'oil',
#   'onion',
#   'raw rice',
#   'salt and pepper',
#   'water'],
#  ['frozen spinach', 'onion', 'parmesan cheese', 'yogurt'],
#  ['baking powder',
#   'baking soda',
#   'beet',
#   'cinnamon',
#   'egg',
#   'flour',
#   'sugar',
#   'vanilla',
#   'vegetable oil',
#   'walnut'],
#  ['cayenne pepper',
#   'chili powder',
#   'cumin',
#   'garlic powder',
#   'nutritional yeast',
#   'onion powder',
#   'paprika',
#   'sea salt'],
#  ['baking powder',
#   'baking soda',
#   'butter',
#   'cinnamon',
#   'egg',
#   'egg white',
#   'granulated sugar',
#   'low fat buttermilk',
#   'nutmeg',
#   'salt',
#   'unsweetened applesauce',
#   'vanilla',
#   'white whole wheat flour'],
#  ['all purpose flour', 'butter', 'cinnamon sugar', 'egg', 'milk'],
#  ['fresh cilantro leaf',
#   'fresh lemon juice',
#   'fresh lime juice',
#   'garlic',
#   'green onion',
#   'ground coriander',
#   'ground cumin',
#   'jalapeno',
#   'onion',
#   'plum tomato',
#   'sea salt',
#   'sugar'],
#  ['apple', 'banana', 'fresh pineapple', 'fresh spinach', 'green grape', 'ice'],
#  ['all purpose flour',
#   'butter',
#   'cheddar cheese',
#   'milk',
#   'onion',
#   'salt',
#   'small shell pasta',
#   'tomato'],
#  ['chicken broth',
#   'cooking oil',
#   'fish sauce',
#   'fresh garlic',
#   'garlic powder',
#   'oyster sauce',
#   'soy sauce',
#   'yakisoba noodle'],
#  ['celery seed',
#   'chive',
#   'cocoa',
#   'dried basil',
#   'dried oregano',
#   'dried parsley',
#   'green bell pepper',
#   'lemon juice',
#   'lemon peel',
#   'tomato ketchup'],
#  ['balsamic vinegar',
#   'canola oil',
#   'dry mustard',
#   'fresh basil',
#   'fresh dill',
#   'fresh sage',
#   'pepper',
#   'red wine vinegar',
#   'salt'],
#  ['chickpea flour',
#   'cornstarch',
#   'soy coffee creamer',
#   'soymilk',
#   'vegetable oil',
#   'whole wheat bread'],
#  ['butter',
#   'cayenne pepper',
#   'cheddar cheese',
#   'cheez whiz',
#   'flour',
#   'macaroni',
#   'milk',
#   'mozzarella cheese',
#   'onion',
#   'paprika',
#   'salt'],
#  ['cream cheese',
#   'creamy peanut butter',
#   'egg',
#   'food cake mix',
#   'light cream',
#   'milk',
#   'powdered sugar',
#   'sour cream',
#   'vanilla',
#   'vegetable oil'],
#  ['breadcrumb', 'egg', 'milk', 'oil', 'salt', 'zucchini'],
#  ['black pepper',
#   'celery',
#   'cream of potato soup',
#   'egg noodle',
#   'frozen corn',
#   'frozen pea',
#   'garlic',
#   'green onion',
#   'ground beef',
#   'milk',
#   'onion powder',
#   'parmesan cheese',
#   'warm water',
#   'worcestershire sauce'],
#  ['applesauce',
#   'baking soda',
#   'carrot',
#   'cinnamon',
#   'crushed pineapple',
#   'egg',
#   'flaked coconut',
#   'flour',
#   'raisin',
#   'salt',
#   'sugar',
#   'tart apple',
#   'vanilla',
#   'vegetable oil',
#   'walnut'],
#  ['blackening seasoning', 'salmon fillet'],
#  ['bisquick',
#   'chive',
#   'deli ham',
#   'egg',
#   'gruyere cheese',
#   'milk',
#   'nonstick cooking spray',
#   'red onion',
#   'salt',
#   'shredded cheddar cheese',
#   'sugar',
#   'unsalted butter'],
#  ['cream of tartar',
#   'egg',
#   'low fat cottage cheese',
#   'splenda sugar substitute'],
#  ['all purpose flour',
#   'baking powder',
#   'baking soda',
#   'buttermilk',
#   'cocoa powder',
#   'egg',
#   'hot coffee',
#   'red food coloring',
#   'salt',
#   'sugar',
#   'vanilla extract',
#   'vegetable oil',
#   'white distilled vinegar'],
#  ['fat free half and half',
#   'nonfat milk',
#   'semi sweet chocolate chip',
#   'sugar',
#   'unsweetened baking cocoa',
#   'vanilla'],
#  ['all purpose flour',
#   'butterscotch chip',
#   'cocoa powder',
#   'cream cheese',
#   'egg',
#   'powdered sugar',
#   'salt',
#   'semi sweet chocolate chip',
#   'shortening',
#   'sour cream',
#   'sugar',
#   'unsalted butter',
#   'vanilla',
#   'vanilla wafer crumb',
#   'white chocolate chip'],
#  ['ginger juice',
#   'honey',
#   'lemon juice',
#   'mayonnaise',
#   'rice vinegar',
#   'sesame oil',
#   'soy sauce'],
#  ['butter bud', 'buttermilk', 'margarine', 'vegetable oil'],
#  ['almond extract',
#   'cornstarch',
#   'graham cracker crumb',
#   'lemon juice',
#   'lemon zest',
#   'maple syrup',
#   'salt',
#   'silken tofu',
#   'slivered almond',
#   'soymilk',
#   'sugar',
#   'tahini'],
#  ['cheddar cheese soup',
#   'cream of chicken soup',
#   'four cheese mexican blend cheese',
#   'frozen fish stick',
#   'frozen hash brown potato',
#   'mayonnaise',
#   'onion',
#   'spicy brown mustard',
#   'sweet pickle relish'],
#  ['garlic powder',
#   'margarine',
#   'mozzarella cheese',
#   'parmesan cheese',
#   'pepperoni slice',
#   'pizza crust mix',
#   'tap water'],
#  ['baking powder', 'olive oil', 'salt', 'unbleached flour', 'water'],
#  ['cayenne pepper',
#   'dinner roll',
#   'fat free sour cream',
#   'fresh cilantro',
#   'garlic clove',
#   'hot pepper sauce',
#   'jalapeno pepper',
#   'lean ground turkey',
#   'lettuce',
#   'light beer',
#   'monterey jack pepper cheese',
#   'pepper',
#   'salsa',
#   'salt'],
#  ['egg', 'french vanilla cake mix', 'vegetable oil'],
#  ['boneless chicken breast',
#   'brown sugar',
#   'canola oil',
#   'cider vinegar',
#   'cornstarch',
#   'egg',
#   'flour',
#   'ginger',
#   'green pepper',
#   'ketchup',
#   'mandarin orange',
#   'oil',
#   'onion',
#   'pepper',
#   'red pepper',
#   'salt'],
#  ['american cheese', 'bacon', 'bisquick', 'egg', 'milk', 'syrup'],
#  ['butter',
#   'cinnamon',
#   'cooked sweet potato',
#   'egg',
#   'flour',
#   'light brown sugar',
#   'milk',
#   'pecan',
#   'sugar',
#   'vanilla'],
#  ['banana', 'creamy peanut butter', 'milk', 'unsweetened cocoa powder'],
#  ['baking soda',
#   'butter',
#   'chocolate chip',
#   'cinnamon',
#   'flour',
#   'ground clove',
#   'nutmeg',
#   'raisin',
#   'salt',
#   'tomato soup',
#   'water',
#   'white sugar'],
#  ['artichoke', 'broth', 'garlic clove', 'lemon', 'olive oil', 'sea salt'],
#  ['butter', 'flour', 'milk', 'pepper', 'poultry seasoning', 'salt'],
#  ['cheddar cheese',
#   'corn tortilla chip',
#   'refried bean',
#   'salsa',
#   'sour cream'],
#  ['active dry yeast',
#   'all purpose flour',
#   'cornmeal',
#   'egg white',
#   'margarine',
#   'salt',
#   'water'],
#  ['banana pepper',
#   'corn syrup',
#   'crouton',
#   'dole italian salad variety',
#   'fresh garlic clove',
#   'italian seasoning',
#   'jumbo black olive',
#   'lemon juice',
#   'mayonnaise',
#   'parmesan cheese',
#   'parsley flake',
#   'pepper',
#   'purple onion',
#   'rom tomato',
#   'romano cheese',
#   'sugar',
#   'vegetable oil',
#   'white vinegar'],
#  ['bacon',
#   'brown sugar',
#   'butter bean',
#   'ground beef',
#   'ketchup',
#   'kidney bean',
#   'liquid smoke',
#   'onion',
#   'pepper',
#   'pork and bean',
#   'salt',
#   'white vinegar'],
#  ['black pepper',
#   'boneless skinless chicken breast',
#   'feta cheese',
#   'fresh parsley',
#   'green pepper',
#   'lemon juice',
#   'rom tomato',
#   'salt',
#   'scallion'],
#  ['bisquick', 'fruit', 'powdered sugar', 'syrup', 'water'],
#  ['butter',
#   'miniature marshmallow',
#   'peanut butter chip',
#   'salted peanut',
#   'sweetened condensed milk'],
#  ['all purpose flour',
#   'baking powder',
#   'baking soda',
#   'boiling water',
#   'butter',
#   'egg',
#   'heavy cream',
#   'light cream',
#   'salt',
#   'semisweet chocolate piece',
#   'sugar',
#   'sugar',
#   'unsweetened cocoa',
#   'vanilla',
#   'vanilla extract'],
#  ['beef bouillon cube',
#   'brown gravy mix',
#   'cream of mushroom soup',
#   'frozen meatball',
#   'water'],
#  ['beer', 'carbonated lemon lime beverage', 'ice', 'lemon twist'],
#  ['carrot',
#   'lemon juice',
#   'lemon zest',
#   'mayonnaise',
#   'pecan',
#   'raisin',
#   'salt',
#   'sugar'],
#  ['butter',
#   'egg',
#   'flour',
#   'lemon extract',
#   'powdered sugar',
#   'sour cream',
#   'vanilla'],
#  ['egg',
#   'ground beef',
#   'ketchup',
#   'milk',
#   'oatmeal',
#   'onion',
#   'prepared mustard',
#   'salt',
#   'sugar',
#   'vinegar'],
#  ['non fat cooking spray', 'potato', 'salt'],
#  ['baking potato', 'cajun seasoning', 'oil', 'salt and pepper'],
#  ['all purpose flour',
#   'baking cocoa',
#   'baking soda',
#   'butter',
#   'carrot',
#   'chocolate frosting',
#   'egg',
#   'plain yogurt',
#   'salt',
#   'sugar',
#   'vanilla extract',
#   'zucchini'],
#  ['canning salt',
#   'cayenne',
#   'dill',
#   'dill pickle',
#   'garlic clove',
#   'onion',
#   'vinegar',
#   'water'],
#  ['all purpose flour',
#   'bread machine yeast',
#   'honey',
#   'margarine',
#   'powdered milk',
#   'salt',
#   'sugar',
#   'water'],
#  ['cool whip',
#   'milk',
#   'sugar',
#   'vanilla flavoring',
#   'vanilla instant pudding mix'],
#  ['black pepper',
#   'dry onion soup mix',
#   'hot water',
#   'margarine',
#   'parsley flake',
#   'potato'],
#  ['knorr vegetable soup mix', 'sour cream', 'tabasco sauce'],
#  ['baking soda',
#   'brown sugar',
#   'butter',
#   'chocolate chip',
#   'egg',
#   'flour',
#   'oat',
#   'sugar',
#   'sweetened condensed milk',
#   'vanilla'],
#  ['baking soda',
#   'brown sugar',
#   'butter',
#   'egg',
#   'granulated sugar',
#   'macadamia nut',
#   'salt',
#   'unbleached white flour',
#   'vanilla',
#   'white chocolate chip'],
#  ['banana', 'honey', 'milk'],
#  ['boiling water',
#   'carrot',
#   'lemon juice',
#   'margarine',
#   'parsley',
#   'salt',
#   'sugar substitute'],
#  ['beef broth',
#   'flour',
#   'garlic clove',
#   'oil',
#   'onion',
#   'pepper',
#   'round steak',
#   'salt'],
#  ['beef broth',
#   'brown sugar',
#   'chili powder',
#   'crushed red pepper flake',
#   'granulated sugar',
#   'liquid smoke',
#   'prepared yellow mustard',
#   'salt',
#   'tomato paste',
#   'white vinegar',
#   'worcestershire sauce'],
#  ['all purpose flour',
#   'baking powder',
#   'egg',
#   'instant espresso powder',
#   'parchment paper',
#   'salt',
#   'semi sweet chocolate chip',
#   'semisweet chocolate',
#   'sugar',
#   'unsalted butter',
#   'unsweetened chocolate',
#   'vanilla extract'],
#  ['canned pinto bean',
#   'corn kernel',
#   'diced tomato with juice',
#   'dried oregano',
#   'fresh cilantro',
#   'garlic clove',
#   'green pepper',
#   'ground cumin',
#   'hot chili pepper',
#   'olive oil',
#   'onion',
#   'salt freshly ground black pepper',
#   'sugar pumpkin',
#   'vegetable stock'],
#  ['black pepper',
#   'blue cheese',
#   'cheddar cheese',
#   'cream cheese',
#   'garlic',
#   'milk',
#   'nut',
#   'worcestershire sauce'],
#  ['semi sweet chocolate chip', 'strawberry', 'white chocolate'],
#  ['dry red wine',
#   'garlic clove',
#   'grainy mustard',
#   'horseradish',
#   'olive oil',
#   'onion',
#   'pork loin chop',
#   'ranch dressing',
#   'sour cream'],
#  ['garlic powder',
#   'ground pepper',
#   'ground sage',
#   'nutritional yeast',
#   'pasta',
#   'salt',
#   'soy margarine',
#   'turmeric',
#   'vanilla flavored soymilk',
#   'vegan mayonnaise'],
#  ['angostura bitter', 'ginger beer', 'vodka'],
#  ['chocolate graham cracker',
#   'cool whip lite',
#   'miniature chocolate chip',
#   'raspberry spreadable fruit'],
#  ['butter',
#   'chocolate chip',
#   'egg',
#   'flour',
#   'maraschino cherry',
#   'miniature marshmallow',
#   'nut',
#   'piece',
#   'raisin',
#   'salt',
#   'sugar',
#   'unsweetened cocoa',
#   'vanilla'],
#  ['baking powder',
#   'butter',
#   'chocolate chip',
#   'egg',
#   'flour',
#   'milk',
#   'sugar'],
#  ['all purpose flour',
#   'asiago cheese',
#   'cheddar cheese',
#   'cheese sauce',
#   'dried chipotle powder',
#   'garlic powder',
#   'gruyere',
#   'low fat milk',
#   'macaroni',
#   'medium cheddar',
#   'mozzarella cheese',
#   'pasta',
#   'salt',
#   'unsalted butter',
#   'water'],
#  ['extra virgin olive oil',
#   'fresh coarse ground black pepper',
#   'fresh lemon juice',
#   'garlic',
#   'mozzarella cheese',
#   'parmesan cheese',
#   'romano cheese'],
#  ['butter', 'egg noodle'],
#  ['dried basil',
#   'dried oregano',
#   'dried rosemary',
#   'egg',
#   'fresh parsley',
#   'garlic clove',
#   'green bell pepper',
#   'ground beef',
#   'mozzarella cheese',
#   'mushroom',
#   'onion',
#   'parmesan cheese',
#   'spinach',
#   'sweet italian sausage link',
#   'tomato paste',
#   'tomato sauce',
#   'water',
#   'whole milk ricotta cheese',
#   'zucchini'],
#  ['baby carrot',
#   'baby potato',
#   'boneless lamb shoulder',
#   'cabbage',
#   'flour',
#   'fresh parsley',
#   'fresh thyme',
#   'garlic clove',
#   'green pea',
#   'lamb broth',
#   'parsnip',
#   'pepper',
#   'salt',
#   'sweet onion',
#   'whiskey'],
#  ['active dry yeast',
#   'boiling water',
#   'brown sugar',
#   'egg',
#   'honey',
#   'oil',
#   'salt',
#   'smart balance butter spread',
#   'sugar',
#   'water',
#   'whole wheat flour'],
#  ['bourbon', 'grand marnier', 'pineapple juice', 'vodka'],
#  ['butter', 'cream cheese', 'green olive', 'green onion', 'walnut'],
#  ['bacon',
#   'colby monterey jack cheese',
#   'dill pickle',
#   'lean ground beef',
#   'lettuce',
#   'prepared mustard',
#   'prepared pizza crust',
#   'thousand island dressing',
#   'tomato'],
#  ['bamboo skewer',
#   'cinnamon',
#   'coconut milk',
#   'earth balance margarine',
#   'fresh cilantro',
#   'fresh ginger',
#   'fresh ground black pepper',
#   'fresh lemon juice',
#   'frozen pea',
#   'garam masala',
#   'garlic clove',
#   'ground coriander',
#   'ground cumin',
#   'ground red pepper',
#   'paprika',
#   'salt',
#   'soy yogurt',
#   'tomato sauce',
#   'vegan chicken'],
#  ['fresh green bean',
#   'garlic clove',
#   'oyster sauce',
#   'peanut oil',
#   'soy sauce',
#   'white sugar'],
#  ['barley', 'beef broth', 'frozen mixed vegetable', 'ground beef', 'tomato'],
#  ['dried cranberry',
#   'grape nut cereal',
#   'light corn syrup',
#   'peanut butter',
#   'rolled oat',
#   'sliced almond',
#   'sugar'],
#  ['cocoa powder', 'date', 'frozen raspberry', 'walnut'],
#  ['barbecue seasoning',
#   'boneless beef chuck roast',
#   'fresh ground black pepper',
#   'garlic powder',
#   'old bay seasoning',
#   'onion powder',
#   'salt',
#   'seasoned salt',
#   'soy sauce'],
#  ['cayenne pepper',
#   'fat cottage cheese',
#   'garlic clove',
#   'jalapeno pepper',
#   'mushroom'],
#  ['extra virgin olive oil',
#   'fresh curly leaf parsley',
#   'garlic',
#   'juice of',
#   'mushroom',
#   'salt and pepper'],
#  ['baby spinach',
#   'bird eye chile',
#   'boneless skinless chicken breast',
#   'cherry tomato',
#   'chicken stock',
#   'fresh basil',
#   'fresh ginger',
#   'garlic clove',
#   'ground coriander',
#   'juice and zest of',
#   'juice and zest of',
#   'lime wedge',
#   'portabella mushroom',
#   'thai fish sauce'],
#  ['amaretto', 'vanilla vodka'],
#  ['black pepper',
#   'cheddar cheese',
#   'heavy cream',
#   'kosher salt',
#   'parmesan cheese',
#   'potato',
#   'sweet onion'],
#  ['butter',
#   'compressed yeast',
#   'egg',
#   'egg',
#   'egg yolk',
#   'flour',
#   'fresh lemon rind',
#   'glace pineapple',
#   'icing sugar',
#   'milk',
#   'mixed peel',
#   'oil',
#   'rum',
#   'salt',
#   'sugar',
#   'sultana',
#   'water'],
#  ['barbecue sauce',
#   'cayenne',
#   'dry mustard',
#   'ginger ale',
#   'light brown sugar',
#   'onion',
#   'paprika',
#   'pepper',
#   'pork butt',
#   'salt',
#   'sugar'],
#  ['garlic',
#   'green onion',
#   'hot chili oil',
#   'natural style peanut butter',
#   'rice wine',
#   'soy sauce',
#   'spaghetti',
#   'sugar'],
#  ['honeydew melon', 'papaya', 'pineapple'],
#  ['chocolate chip',
#   'flaked coconut',
#   'sweetened condensed milk',
#   'vanilla extract'],
#  ['ground cardamom',
#   'olive oil',
#   'rice vermicelli',
#   'rose water',
#   'saffron',
#   'sugar',
#   'water'],
#  ['active dry yeast', 'bread flour', 'canola oil', 'salt', 'sugar', 'water'],
#  ['butter', 'creamed corn', 'egg', 'jiffy corn muffin mix', 'sugar'],
#  ['chicken base',
#   'garlic powder',
#   'kosher salt',
#   'msg',
#   'potassium chloride',
#   'water'],
#  ['basil leaf',
#   'black pepper',
#   'cream',
#   'salt',
#   'sweet unsalted butter',
#   'tomato juice',
#   'whole canned tomato'],
#  ['all purpose flour',
#   'boneless skinless chicken thigh',
#   'cilantro',
#   'dried chipotle powder',
#   'garlic clove',
#   'green chilies',
#   'ground coriander',
#   'ground cumin',
#   'lime juice',
#   'onion',
#   'pepper',
#   'salt',
#   'vegetable oil',
#   'white kidney bean'],
#  ['candy sprinkle',
#   'decorative candy',
#   'egg',
#   'flaked coconut',
#   'lemon cake mix',
#   'miniature chocolate chip',
#   'vegetable oil'],
#  ['butter',
#   'cayenne powder',
#   'cream of mushroom soup',
#   'frozen pea',
#   'imitation crabmeat',
#   'marsala wine',
#   'milk',
#   'mushroom',
#   'parsley',
#   'salt and pepper',
#   'sour cream',
#   'wide egg noodle'],
#  ['active dry yeast',
#   'bread flour',
#   'brown sugar',
#   'butter',
#   'dry milk',
#   'egg',
#   'ground cinnamon',
#   'heavy cream',
#   'imitation vanilla',
#   'karo light corn syrup',
#   'pecan',
#   'salt',
#   'sugar',
#   'warm water'],
#  ['chocolate milk', 'instant chocolate pudding mix', 'vanilla'],
#  ['cinnamon', 'milk', 'nutmeg', 'raisin', 'rice', 'salt', 'sugar', 'vanilla'],
#  ['egg',
#   'garlic powder',
#   'hot pork sausage',
#   'pizza sauce',
#   'refrigerated pie crust'],
#  ['boneless skinless chicken breast',
#   'carrot',
#   'cream of chicken soup',
#   'dry fettuccine',
#   'fat free chicken broth',
#   'water'],
#  ['bacon grease',
#   'beau monde seasoning',
#   'black pepper',
#   'cayenne pepper',
#   'fresh mushroom',
#   'head of cabbage',
#   'margarine',
#   'onion',
#   'pam cooking spray',
#   'salt',
#   'seasoning salt'],
#  ['basil',
#   'breadcrumb',
#   'caraway seed',
#   'egg',
#   'fennel seed',
#   'ground meat substitute',
#   'milk',
#   'minced garlic clove',
#   'oregano',
#   'parmesan cheese',
#   'parsley',
#   'pine nut'],
#  ['basil',
#   'boneless chicken breast half',
#   'butter',
#   'dried parsley',
#   'green onion',
#   'oregano',
#   'parmesan cheese',
#   'seasoned bread crumb',
#   'swiss cheese',
#   'white wine'],
#  ['black bean',
#   'boiling water',
#   'celery rib',
#   'chicken bouillon cube',
#   'cornstarch',
#   'cumin',
#   'garlic clove',
#   'juice of',
#   'onion',
#   'red bell pepper',
#   'salt'],
#  ['bacon',
#   'double cream',
#   'garlic',
#   'gruyere cheese',
#   'olive oil',
#   'parsley',
#   'red potato',
#   'salt and black pepper'],
#  ['basil leaf',
#   'extra virgin olive oil',
#   'fresh basil leaf',
#   'fresh ground black pepper',
#   'garlic',
#   'green tomato',
#   'pine nut',
#   'sea salt',
#   'zucchini'],
#  ['all purpose flour',
#   'brown sugar',
#   'dark corn syrup',
#   'ground cinnamon',
#   'ground nutmeg',
#   'nonfat milk',
#   'orange zest',
#   'raisin',
#   'sugar',
#   'table salt',
#   'vegetable oil',
#   'yeast'],
#  ['baking powder',
#   'baking soda',
#   'buttermilk',
#   'dried fruit',
#   'granulated sugar',
#   'half and half',
#   'light butter',
#   'old fashioned oat',
#   'salt',
#   'sugar',
#   'vanilla extract',
#   'wheat flour'],
#  ['brown sugar',
#   'ground allspice',
#   'ground cinnamon',
#   'ground ginger',
#   'onion',
#   'rhubarb',
#   'salt',
#   'seedless raisin',
#   'vinegar'],
#  ['catsup',
#   'horseradish',
#   'lemon juice',
#   'pepper',
#   'salt',
#   'worcestershire sauce'],
#  ['butter', 'corn', 'fresh cilantro', 'green onion', 'tomato'],
#  ['blackstrap molasses',
#   'cinnamon',
#   'ground flax seed',
#   'honey',
#   'nutmeg',
#   'oil',
#   'rolled oat',
#   'salt',
#   'sugar free applesauce',
#   'vanilla extract',
#   'wheat germ',
#   'whole wheat pastry flour'],
#  ['bread',
#   'butter',
#   'chicken broth',
#   'dry sherry',
#   'flour',
#   'fresh mushroom',
#   'green pepper',
#   'oil',
#   'onion',
#   'parsley',
#   'pork chop',
#   'poultry seasoning',
#   'salt'],
#  ['beef bouillon',
#   'chili powder',
#   'chopped tomato',
#   'garlic clove',
#   'green bell pepper',
#   'olive oil',
#   'onion',
#   'rice',
#   'salt',
#   'water'],
#  ['butter',
#   'chocolate chip',
#   'golden syrup',
#   'nut',
#   'porridge oat',
#   'raisin',
#   'sugar'],
#  ['butter',
#   'chicken broth',
#   'cilantro',
#   'garlic clove',
#   'green chilies',
#   'lime juice',
#   'onion',
#   'rice',
#   'salt'],
#  ['black pepper',
#   'cayenne',
#   'dried oregano',
#   'garlic powder',
#   'paprika',
#   'salt'],
#  ['apple',
#   'baking powder',
#   'baking soda',
#   'carrot',
#   'cinnamon',
#   'egg',
#   'ginger',
#   'hodgson mill multi grain hot cereal',
#   'milk',
#   'nut',
#   'nutmeg',
#   'raisin',
#   'salt',
#   'sugar',
#   'unbleached white flour',
#   'vanilla',
#   'vegetable oil'],
#  ['almond extract',
#   'cinnamon stick',
#   'cranberry juice cocktail',
#   'dark rum',
#   'ginger ale',
#   'lemon juice',
#   'maraschino cherry',
#   'orange',
#   'orange juice',
#   'rum',
#   'unsweetened pineapple juice'],
#  ['boiling water',
#   'butter',
#   'cake mix',
#   'cold water',
#   'cream cheese',
#   'egg yolk',
#   'flour',
#   'granulated sugar',
#   'heavy cream',
#   'semi sweet chocolate chip',
#   'unflavored gelatin',
#   'vanilla extract',
#   'white chocolate chip'],
#  ['chocolate covered peanut', 'pretzel'],
#  ['bread', 'butter', 'mixed spice', 'sugar', 'vanilla powder'],
#  ['cheese', 'flour tortilla'],
#  ['brut champagne', 'grenadine', 'pineapple juice'],
#  ['boiling water', 'gelatin', 'sugar free jello'],
#  ['basil',
#   'bay leaf',
#   'carrot',
#   'celery rib',
#   'garlic clove',
#   'onion',
#   'oregano',
#   'red pepper flake',
#   'spinach',
#   'tomato',
#   'vegetable broth'],
#  ['broccoli',
#   'cabbage',
#   'carrot',
#   'garlic clove',
#   'lemon juice',
#   'onion',
#   'parsley',
#   'pepper',
#   'red bell pepper',
#   'salt',
#   'swiss chard',
#   'thyme',
#   'vegetable broth',
#   'zucchini'],
#  ['butter', 'milk', 'pepper', 'potato', 'salt'],
#  ['bay leaf',
#   'coffee',
#   'garlic clove',
#   'onion',
#   'oregano',
#   'pork roast',
#   'soy sauce',
#   'vegetable oil'],
#  ['baking powder',
#   'cocoa powder',
#   'flour',
#   'milk',
#   'oil',
#   'salt',
#   'sugar',
#   'vanilla extract'],
#  ['fat free refried bean', 'flour tortilla', 'hot taco sauce', 'taco cheese'],
#  ['oil', 'sausage'],
#  ['ham', 'mozzarella cheese', 'pepperoni', 'provolone cheese', 'tortilla'],
#  ['allspice',
#   'brown sugar',
#   'honey',
#   'milk',
#   'no sugar added peanut butter',
#   'raisin bran cereal',
#   'rolled oat',
#   'vanilla',
#   'wheat germ'],
#  ['baking soda',
#   'cocoa',
#   'flour',
#   'salt',
#   'sugar',
#   'vanilla',
#   'vegetable oil',
#   'vinegar',
#   'water'],
#  ['bacon',
#   'cheddar cheese',
#   'frozen potato wedge',
#   'garlic clove',
#   'green onion',
#   'mashed potato',
#   'parmesan cheese',
#   'salt and black pepper',
#   'sour cream'],
#  ['accent seasoning',
#   'chili bean',
#   'chili powder',
#   'cinnamon',
#   'cumin',
#   'diced tomato',
#   'garlic clove',
#   'green bell pepper',
#   'ground beef',
#   'honey',
#   'jalapeno pepper',
#   'salt',
#   'sweet onion',
#   'thyme'],
#  ['baking powder',
#   'butter',
#   'cinnamon',
#   'egg',
#   'flour',
#   'honey',
#   'slivered almond',
#   'sugar',
#   'vanilla extract'],
#  ['biscuit mix', 'ground pork', 'sharp cheddar cheese'],
#  ['cheddar cheese',
#   'cream of mushroom soup',
#   'extra lean ground beef',
#   'frozen tater tot'],
#  ['cooking wine', 'soy sauce', 'sparerib', 'sugar', 'vinegar', 'water'],
#  ['egg', 'flour', 'water'],
#  ['all bran cereal', 'water'],
#  ['apple', 'brown sugar', 'butter', 'cinnamon', 'flour', 'nutmeg', 'oat'],
#  ['balsamic vinegar',
#   'fresh rosemary',
#   'garlic clove',
#   'onion',
#   'red wine',
#   'roasting chicken',
#   'salt and pepper'],
#  ['black bean', 'cumin', 'green chilies', 'thick chunky salsa'],
#  ['boneless skinless chicken breast half',
#   'frozen green bean',
#   'frozen mixed vegetable',
#   'hot pepper sauce',
#   'olive oil'],
#  ['honey',
#   'oil',
#   'rolled oat',
#   'sunflower seed',
#   'vanilla extract',
#   'walnut',
#   'wheat germ'],
#  ['beef broth',
#   'chicken broth',
#   'cooked chicken',
#   'creole seasoning',
#   'french onion soup',
# ...
#   'cracked pepper',
#   'frozen corn',
#   'garlic salt',
#   'green onion',
#   'low sodium chicken broth',
#   'marjoram',
#   'onion',
#   'potato',
#   'salt',
#   'sour cream',
#   'table cream',
#   'water'],
#  ['active dry yeast',
#   'allspice',
#   'brown sugar',
#   'butter',
#   'cinnamon',
#   'citrus peel',
#   'cranberry',
#   'currant',
#   'dried fruit',
#   'golden raisin',
#   'nonfat dry milk powder',
#   'nutmeg',
#   'salt',
#   'unbleached all purpose flour',
#   'warm water',
#   'whole wheat flour'],
#  ['butter',
#   'cream cheese',
#   'egg',
#   'flour',
#   'graham cracker',
#   'ricotta cheese',
#   'sour cream',
#   'sugar',
#   'vanilla extract'],
#  ['bailey irish cream',
#   'coffee liqueur',
#   'dark brown sugar',
#   'maraschino cherry',
#   'rum',
#   'strong coffee',
#   'whipped cream'],
#  ['garlic clove', 'greek oregano', 'lemon', 'olive oil'],
#  ['peach', 'vodka'],
#  ['brown sugar',
#   'cayenne pepper',
#   'cider vinegar',
#   'garlic clove',
#   'ketchup',
#   'onion',
#   'soy sauce',
#   'unsalted butter',
#   'worcestershire sauce'],
#  ['black pepper',
#   'chicken',
#   'garlic paste',
#   'ginger paste',
#   'oil',
#   'red chili powder',
#   'salt',
#   'tomato puree',
#   'yogurt'],
#  ['baby potato',
#   'breadcrumb',
#   'fresh parsley',
#   'garlic clove',
#   'lamb chop',
#   'olive oil',
#   'onion',
#   'parmesan cheese',
#   'salt and pepper',
#   'tomato',
#   'water',
#   'white wine'],
#  ['camembert cheese',
#   'cheddar cheese',
#   'fresh ground black pepper',
#   'garlic clove',
#   'green peppercorn',
#   'lemon thyme leaf',
#   'parsley',
#   'roquefort cheese',
#   'salted butter',
#   'stilton cheese',
#   'unsalted butter'],
#  ['baking powder',
#   'egg white',
#   'flour',
#   'milk',
#   'salt',
#   'sugar',
#   'vanilla',
#   'vegetable shortening'],
#  ['black pepper',
#   'carrot',
#   'chicken broth',
#   'dried oregano',
#   'frozen pea',
#   'lemon juice',
#   'onion',
#   'quinoa',
#   'salt',
#   'vegetable oil'],
#  ['cheese',
#   'deli ham',
#   'greek olive',
#   'green pepper',
#   'hoagie roll',
#   'olive oil',
#   'onion',
#   'red wine vinegar',
#   'salt and pepper',
#   'sour dill pickle',
#   'tomato'],
#  ['hoagie roll', 'mushroom', 'onion', 'provolone cheese', 'rib eye'],
#  ['dried basil',
#   'garlic and cheese flavored crouton',
#   'mozzarella cheese',
#   'red wine vinegar',
#   'tomato'],
#  ['feta',
#   'juice and zest of',
#   'mint leaf',
#   'salt freshly ground black pepper',
#   'watermelon'],
#  ['apricot',
#   'canned pumpkin puree',
#   'cinnamon',
#   'ice',
#   'low fat milk',
#   'nutmeg',
#   'sugar'],
#  ['balsamic vinegar',
#   'black olive',
#   'brown sugar',
#   'egg',
#   'feta cheese',
#   'flaked sea salt',
#   'green olive',
#   'lettuce',
#   'olive oil',
#   'red onion',
#   'salt',
#   'tomato',
#   'vinaigrette dressing'],
#  ['arugula',
#   'balsamic vinegar',
#   'cherry tomato',
#   'coriander',
#   'honey',
#   'olive oil',
#   'red wine',
#   'toasted sesame seed'],
#  ['basil leaf',
#   'black pepper',
#   'blue corn tortilla',
#   'cilantro',
#   'dried ancho chile powder',
#   'extra virgin olive oil',
#   'fresh lime juice',
#   'fresh orange juice',
#   'ground cumin',
#   'kosher salt',
#   'lemon juice',
#   'mango',
#   'olive oil',
#   'peanut oil',
#   'red onion',
#   'red pepper',
#   'salad green',
#   'salt',
#   'sea scallop',
#   'yellow pepper'],
#  ['sugar', 'tea bag', 'water'],
#  ['black bean',
#   'corn',
#   'ground cumin',
#   'hot sauce',
#   'olive oil',
#   'onion',
#   'taco seasoning'],
#  ['butter',
#   'elbow macaroni',
#   'flour',
#   'fresh parmesan cheese',
#   'panko breadcrumb',
#   'salt and pepper',
#   'sharp cheddar cheese',
#   'whole milk'],
#  ['brown sugar',
#   'cayenne',
#   'chicken',
#   'coriander',
#   'garlic clove',
#   'lemon juice',
#   'oil',
#   'onion',
#   'peanut butter',
#   'soya sauce'],
#  ['black olive',
#   'caper',
#   'cucumber',
#   'dried oregano',
#   'feta cheese',
#   'olive oil',
#   'red onion',
#   'sea salt',
#   'tomato'],
#  ['extra virgin olive oil',
#   'fresh lemon juice',
#   'fresh parsley',
#   'hot paprika',
#   'onion',
#   'salt and pepper',
#   'tomato'],
#  ['coconut', 'egg white', 'salt', 'sugar', 'vanilla'],
#  ['bay leaf',
#   'butter',
#   'chicken base',
#   'chicken bouillon cube',
#   'onion',
#   'uncooked rice',
#   'water',
#   'white pepper'],
#  ['apple cider vinegar',
#   'beef brisket',
#   'beer',
#   'black pepper',
#   'black peppercorn',
#   'butter',
#   'canola oil',
#   'chili',
#   'chili powder',
#   'chipotle pepper',
#   'coarse salt',
#   'diced onion',
#   'dried chipotle powder',
#   'fresh cracked pepper',
#   'garlic',
#   'garlic clove',
#   'garlic powder',
#   'honey',
#   'ketchup',
#   'molasses',
#   'mustard powder',
#   'onion flake',
#   'soy sauce',
#   'sugar',
#   'vegetable oil',
#   'water',
#   'worcestershire sauce'],
#  ['all purpose flour',
#   'bay leaf',
#   'boneless skinless chicken thigh',
#   'celery',
#   'diced tomato',
#   'dried italian herb seasoning',
#   'dry white wine',
#   'fresh parsley',
#   'minced garlic clove',
#   'onion',
#   'parmesan cheese',
#   'pasta',
#   'pepper',
#   'salt',
#   'sliced mushroom'],
#  ['baking soda',
#   'brown sugar',
#   'cayenne pepper',
#   'corn syrup',
#   'microwave popcorn',
#   'sea salt',
#   'unsalted butter'],
#  ['cocoa',
#   'cocoa powder',
#   'dark chocolate',
#   'double cream',
#   'paper',
#   'parchment paper',
#   'peanut oil',
#   'preserved gingerroot',
#   'rum',
#   'toasted almond',
#   'unsalted butter'],
#  ['brown onion',
#   'chicken thigh fillet',
#   'chili flake',
#   'chili powder',
#   'cinnamon',
#   'coriander leaf',
#   'cream',
#   'crushed tomato',
#   'fresh ginger',
#   'garam masala',
#   'garlic clove',
#   'green chilies',
#   'ground coriander',
#   'ground cumin',
#   'ground fenugreek',
#   'ground turmeric',
#   'honey',
#   'lemon juice',
#   'paprika',
#   'plain yogurt',
#   'vegetable oil'],
#  ['apple',
#   'baby carrot',
#   'chicken broth',
#   'garlic powder',
#   'ground clove',
#   'ground mustard',
#   'onion',
#   'pepper',
#   'pork tenderloin',
#   'potato',
#   'salt',
#   'thyme'],
#  ['alphabet pasta',
#   'canned beef broth',
#   'fresh parsley',
#   'frozen mixed vegetable',
#   'garlic clove',
#   'italian herb seasoning',
#   'onion',
#   'salt',
#   'stewed tomato',
#   'vegetable oil',
#   'water'],
#  ['bacon',
#   'canned artichoke heart',
#   'celery',
#   'cooked shrimp',
#   'green onion',
#   'mayonnaise',
#   'tomato'],
#  ['curry powder',
#   'honey',
#   'hot sauce',
#   'ketchup',
#   'lemon juice',
#   'mayonnaise',
#   'onion'],
#  ['black olive',
#   'boneless skinless chicken breast',
#   'colby monterey jack cheese',
#   'condensed cream of chicken soup',
#   'corn chip',
#   'evaporated milk',
#   'salsa',
#   'sour cream'],
#  ['butterscotch chip',
#   'chocolate chip',
#   'karo syrup',
#   'peanut butter',
#   'rice krispies',
#   'white sugar'],
#  ['active dry yeast',
#   'butter',
#   'egg',
#   'egg yolk',
#   'flour',
#   'honey',
#   'milk',
#   'salt'],
#  ['bay leaf',
#   'butter',
#   'dried thyme',
#   'garlic clove',
#   'onion',
#   'parsnip',
#   'russet potato',
#   'rutabaga',
#   'salt pepper',
#   'vegetarian chicken broth'],
#  ['canned tomato',
#   'cherry tomato',
#   'chickpea',
#   'cinnamon',
#   'cooking spray',
#   'coriander',
#   'cumin',
#   'dried apricot',
#   'garlic powder',
#   'hot chili powder',
#   'mushroom',
#   'onion',
#   'sweet potato',
#   'tomato puree',
#   'vegetable stock'],
#  ['chive',
#   'cream cheese',
#   'fresh ground black pepper',
#   'mango chutney',
#   'red onion',
#   'small caper',
#   'smoked salmon',
#   'streaky bacon',
#   'whole meal bread'],
#  ['cornstarch', 'cream', 'egg yolk', 'milk', 'sugar', 'vanilla'],
#  ['cold water', 'cornstarch', 'frozen blueberry', 'splenda granular'],
#  ['butter', 'liquid honey', 'salt fresh ground pepper', 'yam'],
#  ['all purpose flour',
#   'baby spinach leaf',
#   'bacon',
#   'cheddar cheese',
#   'cooked boneless skinless chicken breast',
#   'gnocchi',
#   'leek',
#   'parmesan cheese',
#   'skim milk',
#   'unsalted butter'],
#  ['celery salt',
#   'dried rosemary',
#   'egg',
#   'fresh dill',
#   'green onion',
#   'lemon juice',
#   'mozzarella cheese',
#   'pimento pepper',
#   'vegetable oil'],
#  ['cayenne pepper',
#   'ground black pepper',
#   'orange juice',
#   'red wine vinegar',
#   'tomato paste',
#   'whole chicken'],
#  ['condensed tomato soup',
#   'dried oregano',
#   'egg noodle',
#   'garlic clove',
#   'ground beef',
#   'mozzarella cheese',
#   'onion',
#   'salt',
#   'vegetable oil'],
#  ['avocado',
#   'cooked brown rice',
#   'cooked wild rice',
#   'dijon style mustard',
#   'dried apricot',
#   'ground coriander',
#   'honey',
#   'lemon juice',
#   'pecan',
#   'raisin',
#   'red wine vinegar',
#   'safflower oil',
#   'salt and pepper'],
#  ['baking powder',
#   'banana',
#   'butter',
#   'cake flour',
#   'egg',
#   'lemon juice',
#   'lemon rind',
#   'peanut',
#   'salt',
#   'sugar'],
#  ['beef stock',
#   'black pepper',
#   'butter',
#   'carrot',
#   'dried herb',
#   'garlic clove',
#   'lean stewing beef',
#   'onion',
#   'plain flour',
#   'plum tomato',
#   'salt',
#   'self raising flour',
#   'turnip',
#   'vegetable suet',
#   'water'],
#  ['black pepper',
#   'celery seed',
#   'cheddar cheese',
#   'chili powder',
#   'dried onion',
#   'frankfurter',
#   'ground chuck',
#   'ground cumin',
#   'hot dog bun',
#   'salt',
#   'sugar',
#   'tomato paste',
#   'water',
#   'white onion',
#   'worcestershire sauce',
#   'yellow mustard'],
#  ['hot water', 'root beer concentrate', 'seltzer water', 'sugar'],
#  ['celery seed',
#   'chili powder',
#   'ground beef',
#   'onion',
#   'pepper',
#   'salt',
#   'sugar',
#   'tomato puree',
#   'vinegar'],
#  ['celery seed',
#   'chili powder',
#   'cider vinegar',
#   'hamburger',
#   'onion',
#   'pepper',
#   'salt',
#   'sugar',
#   'tomato paste',
#   'tomato puree'],
#  ['all purpose flour',
#   'butter',
#   'chicken base',
#   'granulated garlic',
#   'half and half',
#   'leek',
#   'potato',
#   'salt',
#   'white pepper'],
#  ['garlic clove',
#   'ground ginger',
#   'honey',
#   'hot sauce',
#   'lemon juice',
#   'pork',
#   'soy sauce',
#   'vegetable oil'],
#  ['bacon bit',
#   'cooking spray',
#   'egg',
#   'lean ground beef',
#   'oatmeal',
#   'onion',
#   'original sauce'],
#  ['black cherry',
#   'cherry',
#   'cornstarch',
#   'dark chocolate chip',
#   'double cream brie cheese',
#   'orange',
#   'orange zest',
#   'original sauce',
#   'puff pastry shell',
#   'sugar',
#   'walnut'],
#  ['beer',
#   'chicken leg quarter',
#   'garlic powder',
#   'ground pepper',
#   'italian seasoning',
#   'original sauce'],
#  ['baking powder', 'flour', 'milk', 'salt'],
#  ['ground beef', 'original sauce', 'salt'],
#  ['brown sugar',
#   'lemon juice',
#   'parsley sprig',
#   'prepared mustard',
#   'salad oil',
#   'steak sauce',
#   'underblade steak',
#   'water'],
#  ['beef broth', 'potato', 'round steak', 'spicy brown mustard', 'steak sauce'],
#  ['apple',
#   'apple juice concentrate',
#   'brown sugar',
#   'fresh cranberry',
#   'raisin'],
#  ['apple', 'bologna', 'processed cheese', 'white bread'],
#  ['cilantro leaf',
#   'red chile',
#   'rice vinegar',
#   'salt',
#   'seedless cucumber',
#   'shallot',
#   'sugar'],
#  ['all purpose flour',
#   'apple',
#   'applesauce',
#   'apricot',
#   'baking powder',
#   'baking soda',
#   'banana',
#   'canned pumpkin',
#   'carrot',
#   'cherry',
#   'cinnamon',
#   'crushed pineapple',
#   'date',
#   'egg',
#   'eggplant',
#   'fig',
#   'fresh coconut',
#   'fresh strawberry',
#   'frozen strawberry',
#   'honey',
#   'lemon juice',
#   'marmalade',
#   'mincemeat',
#   'of fresh mint',
#   'orange',
#   'peach',
#   'pear',
#   'prune',
#   'raisin',
#   'raspberry',
#   'rhubarb',
#   'salt',
#   'seedless grape',
#   'sugar',
#   'sweet potato',
#   'tapioca',
#   'tomato',
#   'vanilla extract',
#   'vegetable oil',
#   'walnut',
#   'yam',
#   'yogurt',
#   'zucchini'],
#  ['carrot',
#   'dry breadcrumb',
#   'egg',
#   'ground beef',
#   'milk',
#   'onion',
#   'original sauce',
#   'parsley flake',
#   'tomato sauce'],
#  ['all purpose flour',
#   'brown sugar',
#   'cherry',
#   'dark chocolate',
#   'heavy cream',
#   'mascarpone cheese',
#   'original sauce',
#   'puff pastry sheet',
#   'unsalted butter',
#   'vanilla extract'],
#  ['brown sugar',
#   'cilantro',
#   'extra virgin olive oil',
#   'fresh spinach',
#   'garlic clove',
#   'ginger paste',
#   'green onion',
#   'ground turkey',
#   'onion',
#   'original sauce',
#   'pepper',
#   'red chili pepper',
#   'salt',
#   'water',
#   'wonton wrapper'],
#  ['boysenberry jam',
#   'butter',
#   'chuck eye steak',
#   'fresh ground black pepper',
#   'garlic clove',
#   'garlic powder',
#   'instant polenta',
#   'kosher salt',
#   'lemon juice',
#   'lemon zest',
#   'light brown sugar',
#   'milk',
#   'original sauce',
#   'parmesan cheese',
#   'potato starch',
#   'prepared mustard',
#   'vegetable oil',
#   'water'],
#  ['cauliflower head',
#   'cream of mushroom soup',
#   'french fried onion',
#   'fresh asparagus',
#   'fresh broccoli',
#   'sharp cheddar cheese'],
#  ['blue curacao',
#   'carbonated lemon lime beverage',
#   'gin',
#   'lemon wedge',
#   'light rum',
#   'lime wedge',
#   'maraschino cherry',
#   'sour mix',
#   'tequila',
#   'vodka'],
#  ['boneless skinless chicken thigh',
#   'dijon mustard',
#   'original sauce',
#   'puff pastry',
#   'spinach'],
#  ['cheddar cheese',
#   'cherry tomato',
#   'cream cheese',
#   'cubanelle pepper',
#   'ear of corn',
#   'original sauce',
#   'puff pastry',
#   'roasted potato',
#   'salt and pepper',
#   'sour cream',
#   'steak'],
#  ['beef steak',
#   'cracked black pepper',
#   'garlic clove',
#   'steak sauce',
#   'vegetable oil'],
#  ['dijon mustard',
#   'heinz chili sauce',
#   'heinz ketchup',
#   'orange juice',
#   'orange rind',
#   'raisin',
#   'soy sauce',
#   'white vinegar'],
#  ['bacon',
#   'brown sugar',
#   'cayenne pepper',
#   'cracked black pepper',
#   'extra virgin olive oil',
#   'goat cheese',
#   'ground turkey',
#   'milk',
#   'original sauce',
#   'polenta',
#   'salt',
#   'sharp cheddar cheese',
#   'water'],
#  ['celery',
#   'cider vinegar',
#   'dijon mustard',
#   'garlic powder',
#   'hard boiled egg',
#   'mayonnaise',
#   'onion',
#   'pepper',
#   'potato',
#   'salt',
#   'sugar'],
#  ['black pepper',
#   'cooking oil',
#   'dried lime',
#   'lamb shoulder',
#   'onion',
#   'potato',
#   'salt',
#   'split pea',
#   'turmeric'],
#  ['cilantro',
#   'coriander powder',
#   'cumin powder',
#   'garam masala',
#   'garlic paste',
#   'ginger paste',
#   'green chilies',
#   'onion',
#   'pea',
#   'potato',
#   'salt',
#   'tomato',
#   'turmeric powder',
#   'vegetable oil',
#   'water'],
#  ['cheddar cheese',
#   'chili bean',
#   'corn tortilla',
#   'ground beef',
#   'taco seasoning',
#   'water',
#   'yellow onion'],
#  ['black pepper',
#   'bologna',
#   'garlic powder',
#   'miracle whip',
#   'salt',
#   'sweet pickle relish'],
#  ['black tea leaf',
#   'cinnamon stick',
#   'fresh ginger',
#   'green cardamom pod',
#   'honey',
#   'star anise',
#   'water',
#   'whole clove',
#   'whole milk'],
#  ['black pepper',
#   'cooking oil',
#   'ground lamb',
#   'long grain rice',
#   'of fresh mint',
#   'onion',
#   'salt',
#   'split pea',
#   'turmeric',
#   'turnip'],
#  ['basmati rice',
#   'butter',
#   'fresh chive',
#   'fresh cilantro',
#   'fresh parsley',
#   'fresh spinach',
#   'garlic clove',
#   'ground beef',
#   'ground turmeric',
#   'naan bread',
#   'of fresh mint',
#   'oil',
#   'onion',
#   'salt and black pepper',
#   'water',
#   'yellow split pea',
#   'yogurt'],
#  ['baking soda',
#   'butter',
#   'canola oil',
#   'carrot',
#   'cinnamon',
#   'cream cheese',
#   'crushed pineapple',
#   'egg',
#   'flour',
#   'nut',
#   'powdered sugar',
#   'salt',
#   'sugar',
#   'vanilla'],
#  ['chili', 'cream cheese'],
#  ['boneless skinless chicken breast',
#   'butter',
#   'lemon juice',
#   'mushroom',
#   'parmesan cheese',
#   'parsley',
#   'pepper',
#   'salt',
#   'whipping cream',
#   'white wine',
#   'zest of'],
#  ['canned pumpkin',
#   'egg white',
#   'evaporated milk',
#   'fat free whipped topping',
#   'ground cinnamon',
#   'ground clove',
#   'ground ginger',
#   'ground nutmeg',
#   'salt',
#   'skim milk',
#   'sugar'],
#  ['cinnamon', 'sugar', 'water', 'white rice', 'whole milk'],
#  ['all purpose flour',
#   'baking soda',
#   'butter',
#   'cocoa powder',
#   'egg',
#   'milk chocolate chip',
#   'salt',
#   'semi sweet chocolate chip',
#   'vanilla extract',
#   'white sugar'],
#  ['allspice',
#   'applesauce',
#   'baking powder',
#   'baking soda',
#   'banana',
#   'carrot',
#   'cinnamon',
#   'egg',
#   'olive oil',
#   'sugar',
#   'vanilla',
#   'whole wheat flour'],
#  ['avocado',
#   'broccoli coleslaw mix',
#   'chicken breast half',
#   'low fat ranch dressing',
#   'whole wheat tortilla'],
#  ['bacon',
#   'cheddar cheese',
#   'dijon mustard',
#   'granny smith apple',
#   'multigrain bread'],
#  ['boiling water', 'frozen whole strawberry', 'sugar free jello'],
#  ['dried lemon',
#   'dried white bean',
#   'garbanzo bean',
#   'long grain rice',
#   'meat',
#   'onion',
#   'potato',
#   'salt and pepper',
#   'tomato',
#   'turmeric'],
#  ['cabbage',
#   'carrot',
#   'juice of',
#   'juice of',
#   'pineapple chunk',
#   'salt',
#   'vegetable oil'],
#  ...]

# %%
# calculate average length of each document 
lengths = [len(doc) for doc in corpus]
avg_len = float(sum(lengths)) / len(lengths)
avg_len
# Out:
# 8.926790321898396

# %%
# train word2vec model 
sg = 0 # CBOW: build a language model that correctly predicts the center word given the context words in which the center word appears
workers = 6 # number of CPUs
window = 9 # window size: average length of each document 
min_count = 1 # unique ingredients are important to decide recipes 

model_cbow = Word2Vec(corpus, sg=sg, workers=workers, window=window, min_count=min_count, vector_size=100)

# %%
model_cbow = Word2Vec.load('models/model_cbow.bin')

# %%
#Summarize the loaded model
print(model_cbow)

#Summarize vocabulary
words = list(model_cbow.wv.index_to_key)
words.sort()
# print(words)
# Out:
# Word2Vec(vocab=9868, vector_size=100, alpha=0.025)

# %%
#Acess vector for one word
print(model_cbow.wv['cheese'])
# Out:
# [-0.07361066 -1.8324972   1.1452914   0.34367687  0.2713495  -0.3425753
#  -0.58229494  0.27240643  1.1556298   0.01240388 -0.8318319  -1.0165732
#   0.77112335  0.12960795 -0.9716633   0.17690742  0.8923252  -1.3945265
#   0.290436   -0.04339992  0.7580615   1.1052206   0.8737823   1.5322433
#  -0.0235903  -0.7472721   0.17979541  0.75999284 -1.6583536  -0.23552205
#   1.4295099   1.3505839   1.1024392  -1.0483865   0.49111792  0.7330313
#   0.687744   -2.5379298   0.14389125 -0.5970398  -0.42096147 -0.07966862
#   0.7793348  -0.1823584   0.7442278   0.3127837  -0.00825099  0.5734534
#   1.024176    0.08931772  0.80366546  1.3342966   0.43076077 -1.2120396
#  -0.8316845   0.9720223  -0.08080867  1.8078634  -0.14822097  0.41132224
#   0.06406178  1.6198484   0.39591515  0.24146229  0.162092    0.6233726
#  -1.106728   -0.86356413  0.4644808   0.54935205  0.02982539 -0.00607769
#  -0.28322443  0.8798804   1.063792   -1.1455724   0.6673078  -1.7586339
#   0.26613596  1.4409537   0.9870299   0.87014985 -0.377703   -0.06632984
#  -0.9921979  -0.2591819  -0.8193552   0.09705846 -0.30524173  0.6220134
#   0.5665195  -0.17405932  0.49726227  0.6535042   0.00772653 -0.38060087
#  -0.35823724 -1.096773   -0.09222635 -0.38493755]

# %%
# most similar
model_cbow.wv.most_similar(u'cheese')
#model_cbow.wv.similarity('cheese', 'margarine')
# Out:
# [('cheddar cheese', 0.9109072685241699),
#  ('colby cheese', 0.762747585773468),
#  ('american cheese', 0.7504609227180481),
#  ('colby monterey jack cheese', 0.7120832800865173),
#  ('mild cheddar cheese', 0.6971008777618408),
#  ('chihuahua cheese', 0.6925839781761169),
#  ('low fat cheddar cheese', 0.6763399243354797),
#  ('corn', 0.6734391450881958),
#  ('cottage cheese', 0.6602693796157837),
#  ('black olive', 0.6591867208480835)]

# %%
model_cbow.save('models/model_cbow.bin')

# %%
from word2vec_rec import get_recs

# %%
if __name__ == "__main__":
    # test
    input = "chicken thigh, onion, rice noodle, seaweed nori sheet, sesame, shallot, soy, spinach, star, tofu"
    rec = get_recs(input)
    print(rec)

# %%
input = "chicken thigh, onion, rice noodle, seaweed nori sheet, sesame, shallot, soy, spinach, star, tofu"
rec = get_recs(input)
print(rec)
# Out:
# Successfully loaded model
#                                           recipe               score  \
# 0                                  szechuan fish  0.9242935430919742
# 1     tod mun goong   thai fish and shrimp cakes  0.9213254375755039
# 2  copycat p f  chang s singapore street noodles  0.9169091062273881
# 3   thai chicken and eggplant  aubergine   curry  0.9158816618127215
# 4                                imperial fondue    0.91463966647726
#
#                                          ingredients  \
# 0  red snapper,green onions,garlic,fish stock,soy...
# 1  flounder,shrimp,onion,cilantro,green beans,cor...
# 2  rice noodles,oil,shrimp,boneless skinless chic...
# 3  unsweetened coconut milk,green curry paste,bon...
# 4  boneless skinless chicken,white fish fillet,la...
#
#                                                steps
# 0  ['in a wok brown the fish on all sides with th...
# 1  ['process the onion and cilantro until chopped...
# 2  ['boil rice stick noodles for 2 minutes or unt...
# 3  ['heat coconut milk in wok and whisk curry pas...
# 4  ['prepare the chicken , seafood , vegetables ,...

# %%
class MeanEmbeddingVectorizer(object):

	def __init__(self, word_model):
		self.word_model = word_model
		self.vector_size = word_model.wv.vector_size

	def fit(self):  # comply with scikit-learn transformer requirement
		return self

	def transform(self, docs):  # comply with scikit-learn transformer requirement
		doc_word_vector = self.word_average_list(docs)
		return doc_word_vector

	def word_average(self, sent):
		"""
		Compute average word vector for a single doc/sentence.
		:param sent: list of sentence tokens
		:return:
			mean: float of averaging word vectors
		"""
		mean = []
		for word in sent:
			if word in self.word_model.wv.index_to_key:
				mean.append(self.word_model.wv.get_vector(word))

		if not mean:  # empty words
			# If a text is empty, return a vector of zeros.
			logging.warning("cannot compute average owing to no vector for {}".format(sent))
			return np.zeros(self.vector_size)
		else:
			mean = np.array(mean).mean(axis=0)
			return mean


	def word_average_list(self, docs):
		"""
		Compute average word vector for multiple docs, where docs had been tokenized.
		:param docs: list of sentence in list of separated tokens
		:return:
			array of average word vector in shape (len(docs),)
		"""
		return np.vstack([self.word_average(sent) for sent in docs])

# %%
# encode document by averaging word embeddings

# load model 
loaded_model = Word2Vec.load('models/model_cbow.bin')
if loaded_model:
    print("Successfully loaded model")

mean_vec_tr = MeanEmbeddingVectorizer(loaded_model)
doc_vec = mean_vec_tr.transform(corpus)
# Out:
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# WARNING:root:cannot compute average owing to no vector for []
# Successfully loaded model

# %%
import findspark
findspark.init()

# %%
import pyspark # only run after findspark.init()

# %%
from pyspark import SparkContext, SparkConf, SQLContext
from pyspark.sql import HiveContext 
import pandas as pd

# %%
from pyspark.sql.types import StructType, StructField,StringType,IntegerType
from pyspark.sql import SparkSession

# %%
sc = spark.sparkContext

# %%
spark = SparkSession.builder.appName('Statistics').getOrCreate()

# %%
data = [("James", "Sales", "SG", 70000, 34, 10000),
        ("Michael", "Sales", "SG", 66000, 56, 20000),
        ("Robert", "Sales", "MY", 61000, 30, 23000),
        ("Maria", "Finance", "MY", 60000, 24, 23000),
        ("Raman", "Finance", "USA", 79000, 40, 24000),
        ("Scott", "Finance", "USA", 63000, 36, 19000),
        ("Jen", "Finance", "UK", 89000, 53, 15000),
        ("Jeff", "Marketing", "UK", 70000, 25, 18000),
        ("Alice", "Marketing", "UK", 78000, 50, 21000),
        ("Ada", "IT", "SG", 83000, 35, 11000),
        ("Jackson", "IT", "MY", 71000, 30, 21000),
        ("Cooper", "IT", "UK", 91000, 40, 21000)]

# %%
rdd = sc.parallelize(data)

# %%
df = spark.createDataFrame(rdd, ['employee_name', 'department', 'country', 'salary', 'age', 'bonus'])

# %%
df.show()
df.printSchema()
# Out:
# +-------------+----------+-------+------+---+-----+
# |employee_name|department|country|salary|age|bonus|
# +-------------+----------+-------+------+---+-----+
# |        James|     Sales|     SG| 70000| 34|10000|
# |      Michael|     Sales|     SG| 66000| 56|20000|
# |       Robert|     Sales|     MY| 61000| 30|23000|
# |        Maria|   Finance|     MY| 60000| 24|23000|
# |        Raman|   Finance|    USA| 79000| 40|24000|
# |        Scott|   Finance|    USA| 63000| 36|19000|
# |          Jen|   Finance|     UK| 89000| 53|15000|
# |         Jeff| Marketing|     UK| 70000| 25|18000|
# |        Alice| Marketing|     UK| 78000| 50|21000|
# |          Ada|        IT|     SG| 83000| 35|11000|
# |      Jackson|        IT|     MY| 71000| 30|21000|
# |       Cooper|        IT|     UK| 91000| 40|21000|
# +-------------+----------+-------+------+---+-----+
#
# root
#  |-- employee_name: string (nullable = true)
#  |-- department: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- salary: long (nullable = true)
#  |-- age: long (nullable = true)
#  |-- bonus: long (nullable = true)
